# %% [markdown]
# <a href="https://colab.research.google.com/github/haru1489248/nlp-100-nock/blob/main/ch09/section_82.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 58.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 20.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.36.0
#     Uninstalling huggingface-hub-0.36.0:
#       Successfully uninstalled huggingface-hub-0.36.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.6
#     Uninstalling transformers-4.57.6:
#       Successfully uninstalled transformers-4.57.6
# ...

# %%
from transformers import pipeline

# %%
unmasker = pipeline('fill-mask', model='bert-base-uncased')

# %%
text = "The movie was full of [MASK]."
result = unmasker(text, top_k=10) # 上位10件取得

# %%
print(result)
# Out:
# [{'score': 0.10711909830570221, 'token': 4569, 'token_str': 'fun', 'sequence': 'the movie was full of fun.'}, {'score': 0.06634508073329926, 'token': 20096, 'token_str': 'surprises', 'sequence': 'the movie was full of surprises.'}, {'score': 0.04468429833650589, 'token': 3689, 'token_str': 'drama', 'sequence': 'the movie was full of drama.'}, {'score': 0.027217037975788116, 'token': 3340, 'token_str': 'stars', 'sequence': 'the movie was full of stars.'}, {'score': 0.02541288547217846, 'token': 11680, 'token_str': 'laughs', 'sequence': 'the movie was full of laughs.'}, {'score': 0.019516954198479652, 'token': 2895, 'token_str': 'action', 'sequence': 'the movie was full of action.'}, {'score': 0.019038118422031403, 'token': 8277, 'token_str': 'excitement', 'sequence': 'the movie was full of excitement.'}, {'score': 0.018290264531970024, 'token': 2111, 'token_str': 'people', 'sequence': 'the movie was full of people.'}, {'score': 0.015030632726848125, 'token': 6980, 'token_str': 'tensio
# ...

# %%
for i, item in enumerate(result):
  print(f"尤度：{item['score']}, トークン：{item['token_str']}")
# Out:
# 尤度：0.10711909830570221, トークン：fun
# 尤度：0.06634508073329926, トークン：surprises
# 尤度：0.04468429833650589, トークン：drama
# 尤度：0.027217037975788116, トークン：stars
# 尤度：0.02541288547217846, トークン：laughs
# 尤度：0.019516954198479652, トークン：action
# 尤度：0.019038118422031403, トークン：excitement
# 尤度：0.018290264531970024, トークン：people
# 尤度：0.015030632726848125, トークン：tension
# 尤度：0.014646275900304317, トークン：music
