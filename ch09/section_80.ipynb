# %% [markdown]
# <a href="https://colab.research.google.com/github/haru1489248/nlp-100-nock/blob/main/ch09/section_80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers

# %% [markdown]
# hugging faceが自動でモデル名から推論してくれるAutoTokenizerを使用

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
text = "The movie was full of incomprehensibilities."
tokens = tokenizer.tokenize(text)

# %%
print(tokens)
# Out:
# ['the', 'movie', 'was', 'full', 'of', 'inc', '##omp', '##re', '##hen', '##si', '##bilities', '.']
